# %% [markdown]
# Name:Sam Duran
#
# Andrew ID:sduran
#
# Collaborators (if none, say "none"; do *not* leave this blank):None
#
# Reminder: you should not be sharing code.

# %% [markdown]
# ### Instructions
# 1. Fill in your name, Andrew ID, and collaborators above.
# 2. Fill in the code/text blocks to answer each question.
# 3. Do *not* change any of the existing code provided.
# 4. Run the entire notebook *before* submitting it on Canvas to make sure that the code actually runs without errors. (**Important**: Any code cells that you have entered code for but did not actually execute will be disregarded, so please be sure to actually run your code first and make sure it runs without errors! We may re-run a subset of your code for grading purposes.)
# 5. Be careful about where you save data for use with this Jupyter notebook (more details on this later).

# %% [markdown]
# ### [Problem 1] Basic Text Analysis [45 pts]
#
# This problem involves a mix of Python review (loops, conditionals, counters/dictionaries, sorting) and learning to work with a sizable collection of text data.
#
# You will be looking at a phenomenon of "natural languages" (i.e., human languages, such as English) called *Zipf's law*, which relates how frequently a word occurs in a language to its "rank" (the word with rank 1 is the most frequently occurring word, the word with rank 2 is the second most frequently occurring word, etc). In particular, the word with rank 1 appears twice as likely as the word with rank 2, and the three times as likely as the word with rank 3, and so forth. (Some details on Zipf's law can be found on [Wikipedia](https://en.wikipedia.org/wiki/Zipf%27s_law).) In this problem, you are going to test Zipf's law on a real dataset and explore some of its properties.
#
# **Throughout this problem, do not remove stopwords.**
#
# This problem assumes you have already installed the `spaCy` package ([https://spacy.io](https://spacy.io)). Instructions for installing this are part of the tutorial file "`Anaconda, Jupyter, and spaCy setup tutorial.pdf`". You can find how to access lemmatized tokens using `spaCy` by looking at the `spaCy` demo Jupyter notebook from lecture.
#
# Note: For this problem, you don't actually need `spaCy`'s named entity recognition, grammatical parsing, or part-of-speech tagging. Turning these elements off when you instantiate the nlp object can substantially speed up your code.  To make sure these are off when instantiating the nlp object, call:
#
# `
# nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser', 'tagger'])
# `
#
# The dataset is a collection of the 100 most popular books downloaded from Gutenburg Project ([https://www.gutenberg.org/browse/scores/top](https://www.gutenberg.org/browse/scores/top)); these 100 books form the corpus that we consider for this problem. Each file contains the text of a book. We will read in all 100 books.
#
# Note: Please *do not* change the folder name or the path, and make sure you use a relative path (e.g. './HW1_Dataset/*filename*) when reading the files. When grading your homework, we will put your Jupyter notebook file and the dataset in the same folder, and run your code. **You will not receive points for this problem if your code fails to load the data.**
#
# Hint: To list all files that match a certain pattern, you can use the `glob` package. Here's an example usage:
#
# `
# import glob
# print(glob.glob('./HW1_Dataset/*.txt'))
# `
#
# **(a) [5 pts]** As a warm-up, write a loop that iterates through all 100 books; for each book, print out its corresponding file name and also how long the book is in terms of string length (meaning that if we load in the book as a string, we compute the length of the string using the built-in Python function `len`).
#
# Hint: When debugging your code, you may want to first make sure your code runs on a few of the books rather than all 100 (for example, you can start by only having 3 of the text files in `HW1_Dataset`). Once you're confident that your solution is correct on a few text files, then run on all of them! This is a standard approach to debugging code that is meant to handle large datasets.

# %%
import spacy
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser', 'tagger'])

import glob
file_list = glob.glob('./HW1_Dataset/*.txt')
for i in file_list:
    with open(i,encoding="utf8") as file:
        temp = file.read()
    print(i[14:]+' '+str(len(temp)))
# Out:
# A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (265).txt 177758
# A History of Spanish Literature by James Fitzmaurice-Kelly (109).txt 765918
# A Modest Proposal by Jonathan Swift (233).txt 38966
# A Study in Scarlet by Arthur Conan Doyle (163).txt 262340
# A Tale of Two Cities by Charles Dickens (425).txt 776702
# Adventures of Huckleberry Finn by Mark Twain (401).txt 593962
# Alice in Wonderland by Lewis Carroll and Alice Gerstenberg (126).txt 104079
# Alice's Adventures in Wonderland by Lewis Carroll (564).txt 163817
# Anne of Green Gables by L. M.  Montgomery (114).txt 580635
# Autobiography of Benjamin Franklin by Benjamin Franklin (247).txt 458600
# Beowulf An Anglo-Saxon Epic Poem (403).txt 292953
# Beyond Good and Evil by Friedrich Wilhelm Nietzsche (120).txt 402273
# Candide by Voltaire (180).txt 224924
# Carmilla by Joseph Sheridan Le Fanu (135).txt 176408
# Common Sense by Thomas Paine (297).txt 145353
# Democracy in America — Volume 1 by Alexis de Tocqueville (147).txt 1148435
# Dracula by Bram Stoker (461).txt 867141
# Dubliners by James Joyce (219).txt 389199
# Emma by Jane Austen (166).txt 902390
# Essays by Ralph Waldo Emerson by Ralph Waldo Emerson (239).txt 557197
# Essays of Michel de Montaigne — Complete by Michel de Montaigne (205).txt 3033575
# Et dukkehjem. English by Henrik Ibsen (557).txt 161241
# Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (501).txt 441034
# Great Expectations by Charles Dickens (293).txt 1013450
# Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (429).txt 540241
# Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (136).txt 600105
# Heart of Darkness by Joseph Conrad (213).txt 229835
# Hedda Gabler by Henrik Ibsen (123).txt 193875
# Il Principe. English by Niccolò Machiavelli (428) (Unicode Encoding Conflict).txt 300788
# Jane Eyre_ An Autobiography by Charlotte Brontë (290) (Unicode Encoding Conflict).txt 1049267
# Leaves of Grass by Walt Whitman (164).txt 757361
# Les Misérables by Victor Hugo (165) (Unicode Encoding Conflict).txt 3254333
# Leviathan by Thomas Hobbes (417).txt 1231784
# Liberalism by L. T.  Hobhouse (119).txt 305345
# Metamorphosis by Franz Kafka (483).txt 139056
# Moby Dick; Or, The Whale by Herman Melville (413).txt 1238569
# My Fifteen Lost Years by Florence Elizabeth Maybrick (499).txt 383694
# My Secret Life, Volumes I. to III. by Anonymous (157).txt 1378627
# Narrative of the Captivity and Restoration of Mrs. Mary Rowlandson by Mary White Rowlandson (222).txt 123784
# Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (243).txt 244263
# On Liberty by John Stuart Mill (116).txt 325922
# Outpost in the Wilderness_ Fort Wayne, 1706-1828 by Charles Poinsatte (161).txt 363234
# Persuasion by Jane Austen (2234).txt 486251
# Peter Pan by J. M.  Barrie (274).txt 278194
# Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (160).txt 1154508
# Pride and Prejudice by Jane Austen (1003).txt 704192
# Robert Greene by Robert Greene (126).txt 760655
# Semmering 1912 by Peter Altenberg (221).txt 264946
# Uncle Tom's Cabin by Harriet Beecher Stowe (108).txt 1025501
# Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (180).txt 656207
# War and Peace by graf Leo Tolstoy (251).txt 3227580
# Wuthering Heights by Emily Brontë (179) (Unicode Encoding Conflict).txt 669150

# %% [markdown]
# **(b) [15 pts]** Build a term frequency table for all 100 books. Specifically, building on your solution to part (a), read in a single book at a time and for each book, do the following two steps:
#
#   1. Process the text by separating and lemmatizing the words.
#   2. Count the number of times each word appears in the book and add these to a frequency table. (In particular, use raw counts as the "frequency"--do not divide by the total number of words in the corpus.)
#
# Note that unlike in part (a), this time around, there's no need to print out the file names and how long each book is.
#
# After looping through all 100 books, you should have the term frequency table for the entire corpus (importantly, the frequency table should not just be for a single book; it should be for all 100 books). Sort the table and print the top 50 most frequent words, along with their frequencies and ranks. Don't worry about ties (for example, if multiple things have the same frequency, it's fine if your solution breaks ties arbitrarily in the sorting).
#
# Note: When counting the words, only include words (tokens) that consist of alphabetic letters (a-z and A-Z). You can do this with what's called a *regular expression*. For example, to check whether the words "will.i.am" or "Tesla" are alphabetic, you would do the following:
#
# `
# import re  # regular expression package
# if re.match('[a-zA-Z]+$', 'will.i.am'):
#     print('will.i.am consists only of alphabetic letters!')
# if re.match('[a-zA-Z]+$', 'Tesla'):
#     print('tesla consists only of alphabetic letters!')
# `

# %%
import re
def parse_book(file,dic):
    with open(file,encoding="utf8") as f:
        temp = f.read()
    #handles most cases len < 1000000
    if len(temp) < 1000000:
        parsed_text = nlp(temp)
        for token in parsed_text:
            if re.match('[a-zA-Z]+$', token.orth_):
                if token.orth_ in dic.keys():
                    dic[token.orth_] += 1
                else:
                    dic[token.orth_] = 1
    #handles "war and peace"
    else:
        with open(file,encoding="utf-8") as f:
            temp = f.readlines()
            for i in temp:
                parsed_text = nlp(i)
                for token in parsed_text:
                    if re.match('[a-zA-Z]+$', token.orth_):
                        if token.orth_ in dic.keys():
                            dic[token.orth_] += 1
                        else:
                            dic[token.orth_] = 1
                
    return dic
        
hist = {}

for i in file_list:
    with open(i,encoding="utf8") as file:
        temp = file.read()
        hist = parse_book(i,hist)
        
print(hist)
# Out:
# {'Project': 8147, 'Gutenberg': 8108, 'EBook': 216, 'of': 378234, 'A': 11226, 'Christmas': 272, 'Carol': 5, 'by': 58299, 'Charles': 775, 'Dickens': 15, 'This': 9564, 'eBook': 629, 'is': 101451, 'for': 84944, 'the': 647828, 'use': 4212, 'anyone': 1208, 'anywhere': 515, 'at': 60388, 'no': 31171, 'cost': 767, 'and': 393755, 'with': 97290, 'almost': 4081, 'restrictions': 239, 'whatsoever': 594, 'You': 12940, 'may': 16087, 'copy': 1393, 'it': 115200, 'give': 7873, 'away': 9709, 'or': 44741, 're': 684, 'under': 7481, 'terms': 2627, 'License': 984, 'included': 472, 'this': 50939, 'online': 394, 'Title': 109, 'Ghost': 326, 'Story': 64, 'Author': 163, 'Release': 104, 'Date': 130, 'August': 226, 'Language': 124, 'English': 1654, 'START': 196, 'OF': 4065, 'THIS': 742, 'PROJECT': 615, 'GUTENBER
ly': 303, 'understood': 1243, 'nothing': 8670, 'wonderful': 754, 'can': 19876, 'come': 13084, 'story': 1435, 'am': 13304, 'going': 5154, 'relate': 223, 'If': 9279, 'we': 34548, 'perfectly': 1117, 'convinced': 532, 'Hamlet': 197, 'Father': 1071, 'died': 1546, 'before': 14869, 'play': 1710, 'began': 4800, 'would': 30025, 'more': 24935, 'remarkable': 451, 'taking': 2068, 'stroll': 46, 'night': 7884, 'easterly': 15, 'wind': 1702, 'ramparts': 24, 'than': 19151, 'any': 21022, 'middle': 1216, 'aged': 401, 'gentleman': 1767, 'rashly': 47, 'turning': 1262, ' ...

# %% [markdown]
# **(c) [10 pts]** Visualize the frequency table by plotting a **raw scatter plot** (put frequency as the y-axis and rank as the x-axis), and a **log-log plot** (use logarithmic scales on both the x- and y- axes). Note that this should be for all words and not only the top 50. As before, for the ranks, do not worry about ties, i.e., break ties arbitrarily.

# %%
# Raw scatter plot
from operator import itemgetter
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')

sorted_hist = sorted(hist.items(),
                    reverse=True,
                    key=itemgetter(1))

raw_counts = [i[1] for i in sorted_hist]

plt.scatter(range(1,len(sorted_hist)+1),raw_counts)
plt.xlabel('Word Rank')
plt.ylabel('Raw count')
# Out:
# Text(0, 0.5, 'Raw count')

# %%
# Log-log plot
import numpy as np
log_raw_counts = [np.log(i[1]) for i in sorted_hist]
log_rank = [np.log(i) for i in range(1,len(sorted_hist)+1)]

all_words = len(sorted_hist)

word_count = 0
for i in sorted_hist:
    word_count += i[1]
    
c = 0.1*word_count

def zipf(rank):
    return c * (1/rank)
    
log_zipf = [np.log(zipf(i)) for i in range(1,len(sorted_hist)+1)]
    


plt.scatter(log_rank,log_zipf,label="zipf predicted")
plt.scatter(log_rank,log_raw_counts,label="log_raw_counts")
plt.legend()
plt.xlabel('Log Word Rank')
plt.ylabel('Log Raw count')
# Out:
# Text(0, 0.5, 'Log Raw count')

# %% [markdown]
# **(d) [15 pts]** Explore the frequency table: Zipf's law states that term frequency is governed by a power low, i.e. the relationship between term frequency and rank can be approximated by $f(r) = cr^{-1}$, where $f(r)$ is the frequency of the term at rank $r$, $r$ is the rank of a term, and $c$ is a constant and is approximately 0.1*(corpus size) for English.
#
# Answer following questions:
#
# - What do you observe in the log-log plot above? Is this consist with the power law?

# %% [markdown]
# Your text answer (for this question, your answer is *not* code): According to Zipf's law, you should see a linear relationship between log rank and log raw counts.  This is argueably the case with the mostly linear relationship visible in the chart.  As you move to the lowest ranks, this relationship seems to fall apart in the data we have.

# %% [markdown]
# - Think of the corpus as a (large) unigram bag of words. Following the analogy from lecture, imagine drawing a single word from this big bag (note that we are assuming that we've lemmatized the words and also filtered out non-alphanumeric words). What is the probability of drawing one of the 4 most frequent words? What is the probability of drawing one of the 50 most frequent words? Answer these two questions using code rather than just entering in the final answers as numbers.

# %%
print('Probability of drawing one of the 4 most frequent words: ')

word_prob4 = [i[1]/word_count for i in sorted_hist[0:4]]
print(np.sum(word_prob4))

print('Probability of drawing one of the 50 most frequent words: ')
word_prob50 = [i[1]/word_count for i in sorted_hist[0:50]]
print(np.sum(word_prob50))
# Out:
# Probability of drawing one of the 4 most frequent words:
# 0.14385635366723282
# Probability of drawing one of the 50 most frequent words:
# 0.41890178146993556

# %% [markdown]
# - What proportion of the words occur only once? What proportion of the words occur fewer than 10 times?

# %%
print("Occur only once: ")
count = 0
for i in sorted_hist:
    if i[1] == 1:
        count += 1

proportion_1 = count/all_words
print(proportion_1)

print("Occur fewer than 10 times: ")
count = 0
for i in sorted_hist:
    if i[1] < 10:
        count += 1

proportion_10 = count/all_words
print(proportion_10)
# Out:
# Occur only once:
# 0.41168675891585627
# Occur fewer than 10 times:
# 0.7556640342393249

# %% [markdown]
# ### [Problem 2] Entity Recognition and Pointwise Mutual Information (PMI) [50 pts]
# By using the entity recognition system in `spaCy`, let's identify named entities from newspaper articles. You'll be using Reuters corpus which contains more than ten thousand newspaper articles. To run the code below, you need to download the Reuters dataset. To do so, in a terminal/command line (recall that you can open a terminal from Jupyter's webpage that shows all the files, which by default is [http://localhost:8888/tree](http://localhost:8888/tree)), start up Python and enter:
#
# `
# import nltk
# nltk.download('reuters')
# `
#
# Then proceed to the problem subparts below.
#
# Note that in this problem you will need named entity recognition but not grammatical parsing or the part-of-speech tagging. Hence, you will want to instantiate the nlp object by calling:
#
# `
# nlp = spacy.load('en_core_web_sm', disable=['parser', 'tagger'])
# `

# %% [markdown]
# **(a) [15 pts]** Draw a bar chart in which one of the axes shows entity labels and the other shows the frequency of the corresponding label. Use the variables `reuters_nlp` and `label_counter` provided in the code below.

# %%
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import reuters
import re
import spacy
nlp = spacy.load('en_core_web_sm', disable=['parser', 'tagger'])
reuters_fileids = reuters.fileids()  # hint: when first debugging, consider looking at just the first few
reuters_nlp = [nlp(re.sub('\s+',' ', reuters.raw(i)).strip()) for i in reuters_fileids]
label_counter = Counter()

for i in reuters_nlp:
    for entity in i.ents:
        original_entity_label = entity.label_
        label_counter[original_entity_label] += 1
    
from operator import itemgetter
sorted_entity_label_count_pairs = sorted(label_counter.items(),
                                  reverse=True,
                                  key=itemgetter(1))

entity_counts = [i[1] for i in sorted_entity_label_count_pairs]
entity_labels = [i[0] for i in sorted_entity_label_count_pairs]

# %matplotlib inline    
plt.style.use('seaborn')
plt.bar(range(len(sorted_entity_label_count_pairs)), entity_counts)
plt.xticks(range(len(entity_labels)), entity_labels, rotation=90)
plt.xlabel('Entity Label')
plt.ylabel('Raw count')
# Out:
# Text(0, 0.5, 'Raw count')

# %% [markdown]
# **(b) [15 pts]** Now list the top 10 most frequently occured entities (entity text and the number of occurence) with labels `ORG` (organization) and `GPE` (geopolitical entity such as countries, cities, states) respectively.
#
# Hint: Here, when counting the frequency, we need to count how many articles have an entity with the desired property. For every article, we add 1 if the article has the entity and 0 otherwise.  List filtering (as in Recitation 1) will be helpful here.

# %%
### NOTE I use .lower() as U.S. should be considered the same as u.s.

print("10 Most Frequently Occuring ORG Entities")
ORG_Counter = Counter()
for i in reuters_nlp:
    for entity in i.ents:
        if entity.label_ == "ORG":
            original_entity = entity.text.lower()
            ORG_Counter[original_entity] += 1

sorted_ORG_entity_count_pairs = sorted(ORG_Counter.items(),
                                  reverse=True,
                                  key=itemgetter(1))

for i in sorted_ORG_entity_count_pairs[0:10]:
    print(i)


print("10 Most Frequently Occuring GPE Entities")
GPE_Counter = Counter()
for i in reuters_nlp:
    for entity in i.ents:
        if entity.label_ == "GPE":
            original_entity = entity.text.lower()
            GPE_Counter[original_entity] += 1

sorted_GPE_entity_count_pairs = sorted(GPE_Counter.items(),
                                  reverse=True,
                                  key=itemgetter(1))

for i in sorted_GPE_entity_count_pairs[0:10]:
    print(i)
# Out:
# 10 Most Frequently Occuring ORG Entities
# ('mln', 5405)
# ('pct', 2066)
# ('cts', 1773)
# ('qtr', 1129)
# ('ec', 806)
# ('fed', 641)
# ('opec', 496)
# ('reuters', 491)
# ('usda', 414)
# ('treasury', 349)
# 10 Most Frequently Occuring GPE Entities
# ('u.s.', 4186)
# ('japan', 1487)
# ('the united states', 591)
# ('brazil', 470)
# ('canada', 388)
# ('china', 366)
# ('u.k.', 365)
# ('paris', 342)
# ('washington', 333)
# ('west germany', 314)

# %% [markdown]
# **(c) [20 pts]** Give the top 50 `GPE` (countries, cities, states) entities that have the highest Pointwise Mutual Information (PMI) values with regard to the `ORG` (organization) entity **'opec'** (your list of this top 50 should be ranked in decreasing PMI value). Did you find any unexpected results? If so, why do you think it happened? If you found some of the results to be unsurprisingly, how come?
#
# Hint 1: As in lecture, when computing PMI, we will compute probabilities by counting the number of documents where entities occur or co-occur.  For example, $P('opec') = \frac{number \ \ of \ \ documents \ \ containing \ \ 'opec'}{number \ \ of \ \ documents}$.
#
# Hint 2: To compute this ranking, you do not have to compute the full PMI equation.

# %%
#in using some of the work from above... .lower() is used when finding unique entities.  
art_count = len(reuters_nlp)

def count_entity(entity):
    GPE_article_count = 0
    GPE_opec_co_count = 0
    for i in range(0,len(reuters_nlp)):
        article_entities = []
        for g in reuters_nlp[i].ents:
            article_entities.append(g.text.lower())
        if entity.lower() in article_entities:
            GPE_article_count += 1
            if 'opec' in article_entities:
                GPE_opec_co_count += 1
    return [GPE_article_count, GPE_opec_co_count]       

opec_count = count_entity('opec')[0]

GPE_PMI = {}

#p(opec) is the same for all GPEs involved. Can factor out p(opec) from numerator using chain rule.  Calculated p(GPE|opec)/p(GPE) for ranking.   
for i in sorted_GPE_entity_count_pairs:
    temp = count_entity(i[0])
    GPE_PMI[i[0]] = (temp[1]/opec_count)/(temp[0]/art_count)
# Out:
# {'u.s.': 2.1036269430051813, 'japan': 1.5, 'the united states': 1.8125, 'brazil': 0.0, 'canada': 2.190647482014388, 'china': 0.635036496350365, 'u.k.': 0.9094076655052264, 'paris': 0.9405405405405405, 'washington': 1.1201716738197425, 'west germany': 1.4808510638297872, 'taiwan': 0.0, 'new york': 1.726190476190476, 'london': 1.6415094339622642, 'iran': 10.336633663366335, 'britain': 3.2052631578947364, 'tokyo': 2.3513513513513513, 'france': 1.441988950276243, 'the soviet union': 3.3984375, 'ecuador': 41.28813559322034, 'indonesia': 8.923
0, 'sudan': 0.0, 'finland': 0.0, 'manila': 0.0, 'atlanta': 0.0, 'morocco': 0.0, 'uruguay': 0.0, 'zurich': 0.0, 'jordan': 6.214285714285714, 'allegheny': 0.0, 'pennsylvania': 0.0, 'piedmont': 0.0, 'sydney': 0.0, 'san miguel': 0.0, 'honduras': 0.0, 'sao paulo': 0.0, 'nevada': 0.0, 'west berlin': 0.0, 'libya': 46.4, 'denver': 0.0, 'papua new guinea': 0.0, 'boston': 0.0, 'romania': 0.0, 'qtr': 0.0, 'oregon': 0.0, "hong kong's": 0.0, 'new south wales': 0.0, 'athens': 0.0, 'kimberley': 0.0, 'calgary': 0.0, 'connecticut': 0.0, 'virginia': 0.0, 'the dominican republic': 0.0, 'georgia': 0.0, 'nicaragua': 0.0, 'oman': 17.4, 'first city': 0.0, 'toledo': 0.0, 'alumina': 0.0, 'arizona': 0.0, 'pittsburgh': 0.0, 'nebraska': 0.0, 'jakarta': 23.72727272727273, 'henley': 0.0, 'champlin': 0.0, 'united states': 0.0, 'maryland': 7.90909090909091, 'cleveland': 0.0, 'fort worth': 0.0, 'tanzania': 0.0, 'queensland': 0.0, 'amsterdam': 0.0, 'atlantic city': 0.0, 'st. loui ...

# %%
sorted_GPE_PMI = sorted(GPE_PMI.items(),
                                  reverse=True,
                                  key=itemgetter(1))

for i in range(0,50):
    print(sorted_GPE_PMI[i][0])
# Out:
# neutral zone
# visnews
# adnoc
# emirates
# yanbu
# tripoli
# maracaibo
# i.e.
# miraflores
# bethesda
# bonny
# napo
# napo province
# doha
# venezuela ecuador's
# non-opec mexico
# tihamah
# vienna
# riyadh
# balao
# gabon
# saudi arabia's
# dubai
# quito
# petronas
# caracas
# kingdom
# qatar
# brent
# libya
# nigeria
# port jerome
# statfjord
# north slope
# saudi
# ecuador
# saudi arabia
# kuwait
# hernandez
# the united arab emirates
# venezuela
# lagos
# abu dhabi
# lambert
# pertamina
# jakarta
# jamaica
# san antonio
# alexandria
# tobago

# %% [markdown]
# Your text answer (for this question, your answer is *not* code): Some of top 50 PMI are a bit suprising on one hand, as they seem obscure, but this might might make sense at they have a very low probabily of occuring in the first place (co-occuring with opec in the rare case they show up).   There are many in the list that make sense, as they mark locations in opec countires or other locations related to the global oil and gas industry.
#
# Ranked List of GPEs:
# neutral zone
# visnews
# adnoc
# emirates
# yanbu
# tripoli
# maracaibo
# i.e.
# miraflores
# bethesda
# bonny
# napo
# napo province
# doha
# venezuela ecuador's
# non-opec mexico
# tihamah
# vienna
# riyadh
# balao
# gabon
# saudi arabia's
# dubai
# quito
# petronas
# caracas
# kingdom
# qatar
# brent
# libya
# nigeria
# port jerome
# statfjord
# north slope
# saudi
# ecuador
# saudi arabia
# kuwait
# hernandez
# the united arab emirates
# venezuela
# lagos
# abu dhabi
# lambert
# pertamina
# jakarta
# jamaica
# san antonio
# alexandria
# tobago

# %% [markdown]
# ### [Problem 3] Questionnaire [5 pts]
# Please provide feedback! To receive the 5 points, be sure to enter your Andrew ID correctly in this Google form: https://forms.gle/N3YoCT3dxfpu3HYj6
